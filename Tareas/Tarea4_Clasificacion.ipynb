# %% [markdown]
# # Tarea 4: Comparación de Algoritmos de Clasificación

# %% [markdown]
# En esta tarea consiste en hacer una comparación de los clasificadores visto hasta ahora:
#
# - Naives Bayes
# - Perceptrón
# - Regresión Logística
# - k-Vecinos más Cercanos
# - Árboles de Decisión
# - SVM
# - Random Forrest
# - AdaBoost
#
# Usando los datos contenidos en el archivo `wisc.csv`, los cuales estan basados en el conjunto de datos "Breast Cancer Wisconsin" del repositorio UCI Machine Learning Repository.
#
# - Página UCI: <https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)>
# - Descripción de los Datos: https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.names
#
# Puntos a desarrollar:
# - Dividir los datos con un 20% de los datos para pruebas
# - Convertir datos categóricos a numéricos.
# - Normalizar los atributos.
# - Realizar visualizaciones de los datos.
# - Para cada algoritmo que tenga hiperparámetros, hacer una búsqueda de los mejores valores usando validación cruzada.
# - Graficar las regiones de decisiones para cada uno de los algoritmos.
# - Generar una tabla ordenada por el rendimiento sobre el conjunto de prueba, que muestre la exactitud de entrenamiento, exactitud de prueba y el tiempo de ejecución.
# - Mostrar la matriz de confusión y la curva ROC para cada clasificador
#
# La fecha límite de entrega de la tarea es el día 13 de Abril antes de la clase.

# %%
import pandas as pd
wisc = pd.read_csv('datos/wisc.csv')
wisc.head()
# Out:
#   class  radius  texture  perimeter    area  smoothness  compactness  \
# 0     M   17.99    10.38     122.80  1001.0     0.11840      0.27760
# 1     M   20.57    17.77     132.90  1326.0     0.08474      0.07864
# 2     M   19.69    21.25     130.00  1203.0     0.10960      0.15990
# 3     M   11.42    20.38      77.58   386.1     0.14250      0.28390
# 4     M   20.29    14.34     135.10  1297.0     0.10030      0.13280
#
#    concavity  concave  symmetry  fractal
# 0     0.3001  0.14710    0.2419  0.07871
# 1     0.0869  0.07017    0.1812  0.05667
# 2     0.1974  0.12790    0.2069  0.05999
# 3     0.2414  0.10520    0.2597  0.09744
# 4     0.1980  0.10430    0.1809  0.05883
